# %%
1+1
# Out:
# 2

# %%
(*随机生成10个颜色*)
Table[RandomColor[],10]

(*计算定积分*)
Integrate[x^5+6x+2,{x,-3,2}]

(*三维绘图*)
Plot3D[Sin[x*y],{x,-Pi,Pi},{y,-Pi,Pi}]

(*建立一个有限映射的图*)
# Graph[Table[i -> Mod[i^2, 74], {i, 100}]]
# Out:
# {RGBColor[0.550179, 0.828209, 0.170748], RGBColor[0.804946, 0.0419876, 0.131966],
#
# >   RGBColor[0.806672, 0.115875, 0.308557], RGBColor[0.0117278, 0.976281, 0.0431637],
#
# >   RGBColor[0.629231, 0.19646, 0.324333], RGBColor[0.233119, 0.75084, 0.485811],
#
# >   RGBColor[0.796627, 0.3958, 0.22028], RGBColor[0.211709, 0.0350863, 0.821653],
#
# >   RGBColor[0.0645145, 0.516262, 0.950068], RGBColor[0.315426, 0.232796, 0.653271]}
#   695
# -(---)
#    6
# -Graphics3D-
# Graph[<101>, <100>]

# %%
2+1
# Out:
# 3
